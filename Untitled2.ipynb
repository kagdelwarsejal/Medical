# %% [markdown]
# <a href="https://colab.research.google.com/github/kagdelwarsejal/Medical/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow keras opencv-python-headless matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image_path = '/content/drive/MyDrive/data1/images/bp_262118_4_174545_4_19_jpg.rf.e13b958d6de09b3c22b83af535d6649b.jpeg'  # Change this path if necessary
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_resized = cv2.resize(image, (224, 224))  # Resizing for the CNN

# %%
bbox_path = '/content/drive/MyDrive/data1/labels/bp_262118_4_174545_4_19_jpg.rf.e13b958d6de09b3c22b83af535d6649b.txt'  # Change this path if necessary
bboxes = np.loadtxt(bbox_path)

# %%
# Build a simple CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='linear')  # Output layer for regression
])

model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Dummy training data (for illustration purposes)
X_train = np.array([image_resized])
y_train = np.array([len(bboxes)])  # The count of trees in the image

# Train the model (here we use a dummy training for illustration)
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 6s 6s/step - loss: 21.4782
# Epoch 2/10
# 1/1 [==============================] - 0s 17ms/step - loss: 1747145.7500
# Epoch 3/10
# 1/1 [==============================] - 0s 16ms/step - loss: 38654.7383
# Epoch 4/10
# 1/1 [==============================] - 0s 15ms/step - loss: 206.7940
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 183.3155
# Epoch 6/10
# 1/1 [==============================] - 0s 12ms/step - loss: 45.7993
# Epoch 7/10
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0597
# Epoch 8/10
# 1/1 [==============================] - 0s 11ms/step - loss: 117.7758
# Epoch 9/10
# 1/1 [==============================] - 0s 10ms/step - loss: 134.3286
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 30.5212

# %%
# Predict the number of trees in the image
predicted_count = model.predict(np.array([image_resized]))
print(f"Predicted number of trees: {int(predicted_count[0][0])}")

# Visualize the image with bounding boxes
plt.imshow(image)
plt.title(f"Predicted number of trees: {int(predicted_count[0][0])}")
for bbox in bboxes:
    x_center, y_center, width, height = bbox[1] * image.shape[1], bbox[2] * image.shape[0], bbox[3] * image.shape[1], bbox[4] * image.shape[0]
    x1, y1 = int(x_center - width / 2), int(y_center - height / 2)
    x2, y2 = int(x_center + width / 2), int(y_center + height / 2)
    plt.gca().add_patch(plt.Rectangle((x1, y1), width, height, edgecolor='red', facecolor='none', linewidth=2))
plt.show()
# Out:
# 1/1 [==============================] - 0s 133ms/step
# Predicted number of trees: 27

# %%
# Calculate the actual number of trees in the image
actual_count = len(bboxes)

# Predict the number of trees in the image
predicted_count = model.predict(np.array([image_resized]))
predicted_count = int(predicted_count[0][0])

# Calculate Mean Absolute Error (MAE)
mae = abs(actual_count - predicted_count)

# Calculate Accuracy in percentage
accuracy_percentage = max(0, 100 - (mae / actual_count) * 100)

# Print the results
print(f"Actual number of trees: {actual_count}")
print(f"Predicted number of trees: {predicted_count}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Accuracy: {accuracy_percentage:.2f}%")
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Actual number of trees: 37
# Predicted number of trees: 27
# Mean Absolute Error (MAE): 10
# Accuracy: 72.97%

# %%
actual_count = len(bboxes)

# %%
predicted_count = model.predict(np.array([image_resized]))
predicted_count = int(predicted_count[0][0])
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.image import non_max_suppression
import numpy as np
import cv2

# Load a pretrained Faster R-CNN model
base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))
# Out:
# ...
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
# Resize and preprocess your image for Faster R-CNN
image_resized = cv2.resize(image, (224, 224))
image_preprocessed = preprocess_input(img_to_array(image_resized))
image_preprocessed = np.expand_dims(image_preprocessed, axis=0)

# %%
# Define the RPN (Region Proposal Network) layers based on the backbone
# This is a simplification for illustration; a full Faster R-CNN setup is more complex
# Typically, you'd use a framework like TensorFlow Object Detection API for this

# RPN (Region Proposal Network) layer is usually connected to the base model
# This code provides a simplified structure:
rpn = Conv2D(512, (3, 3), activation='relu', padding='same')(base_model.output)
rpn_class = Conv2D(9 * 2, (1, 1), activation='sigmoid', padding='valid')(rpn) # Two classes: object or not
rpn_bbox = Conv2D(9 * 4, (1, 1), activation='linear', padding='valid')(rpn) # Bounding box coordinates

# Compile the model (for fine-tuning)
model = Model(inputs=base_model.input, outputs=[rpn_class, rpn_bbox])
model.compile(optimizer='adam', loss=['binary_crossentropy', 'mean_squared_error'])

# This is just a structural example; you'll need actual RPN training with ground truth data

# %%
# Step 4: Make Predictions Using the Model

# Assuming rpn_bbox_pred has shape (num_anchors, 4) and rpn_class_pred has shape (num_anchors, 2)
# (Replace this with your model's actual output)
num_anchors = rpn_bbox_pred.shape[0]
boxes = np.random.rand(num_anchors, 4)  # Placeholder for actual bounding box predictions
scores = np.random.rand(num_anchors)    # Placeholder for actual scores

# %%
# Ensure the boxes array is 2D and scores array is 1D
assert boxes.shape == (num_anchors, 4)
assert scores.shape == (num_anchors,)

# %%
# Use non_max_suppression to select the best bounding boxes
selected_indices = non_max_suppression(boxes, scores, max_output_size=5)
selected_boxes = boxes[selected_indices]

# %%
# Visualize the bounding boxes
for box in selected_boxes:
    y1, x1, y2, x2 = box
    cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Calculate the actual number of trees in the image
actual_count = len(bboxes)

# Predict the number of trees in the image
predicted_count = len(selected_boxes)  # Based on the number of selected boxes from non-max suppression

# %%
# Calculate Mean Absolute Error (MAE) and Accuracy Percentage
mae = abs(actual_count - predicted_count)
accuracy_percentage = max(0, 100 - (mae / actual_count) * 100)

print(f"Actual number of trees: {actual_count}")
print(f"Predicted number of trees: {predicted_count}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Accuracy: {accuracy_percentage:.2f}%")
# Out:
# Actual number of trees: 37
# Predicted number of trees: 1
# Mean Absolute Error (MAE): 36
# Accuracy: 2.70%

# %%
# Visualize selected bounding boxes to ensure they correspond to detected trees
for box in selected_boxes:
    y1, x1, y2, x2 = box
    cv2.rectangle(image, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

# Show the image with bounding boxes
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# Print selected_boxes and their count
print(f"Selected Bounding Boxes: {selected_boxes}")
print(f"Predicted number of trees: {len(selected_boxes)}")
# Out:
# Selected Bounding Boxes: [[0.76520308 0.28573952 0.26627201 0.45993878]]
# Predicted number of trees: 1

# %%
# Calculate the actual number of trees in the image
actual_count = len(bboxes)

# Predict the number of trees in the image
predicted_count = len(selected_boxes)  # Based on the number of selected boxes from non-max suppression

# Calculate Mean Absolute Error (MAE) and Accuracy Percentage
mae = abs(actual_count - predicted_count)
accuracy_percentage = max(0, 100 - (mae / actual_count) * 100)

print(f"Actual number of trees: {actual_count}")
print(f"Predicted number of trees: {predicted_count}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Accuracy: {accuracy_percentage:.2f}%")
# Out:
# Actual number of trees: 37
# Predicted number of trees: 1
# Mean Absolute Error (MAE): 36
# Accuracy: 2.70%

# %%
# YOLOv5 Code Implementation

import torch

# %%
# Load YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:293: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: Ultralytics requirements ['gitpython>=3.1.30', 'pillow>=10.3.0', 'requests>=2.32.0'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 8.0 MB/s eta 0:00:00
# ...

# %%
# Load image
img = '/content/drive/MyDrive/data1/images/bp_262118_4_174545_4_19_jpg.rf.e13b958d6de09b3c22b83af535d6649b.jpeg'  # replace with your image path

# %%
# Inference
results = model(img)

# %%
# Results
results.show()  # or results.save() to save predictions
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# You can also get the predictions in a pandas DataFrame
df = results.pandas().xyxy[0]  # xmin, ymin, xmax, ymax, confidence, class, name
print(df)
# Out:
# Empty DataFrame
# Columns: [xmin, ymin, xmax, ymax, confidence, class, name]
# Index: []

# %%
pip install torch torchvision

# %%
pip install git+https://github.com/ultralytics/yolov5.git
# Out:
# ...
#   Cloning https://github.com/ultralytics/yolov5.git to /tmp/pip-req-build-6ht5fzqf
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/yolov5.git /tmp/pip-req-build-6ht5fzqf
#   Resolved https://github.com/ultralytics/yolov5.git to commit 6096750fcc85ee9c45896e81d93d80fd5e33dd2c
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# Get the predictions in a pandas DataFrame
df = results.pandas().xyxy[0]  # xmin, ymin, xmax, ymax, confidence, class, name

# Filter out the detections labeled as "tree"
tree_detections = df[df['name'] == 'tree']

# Count the number of trees detected
tree_count = len(tree_detections)

# Display the count
print(f'Number of trees detected: {tree_count}')
# Out:
# Number of trees detected: 0
